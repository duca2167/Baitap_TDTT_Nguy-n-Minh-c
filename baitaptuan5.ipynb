# %% [markdown]
# #### W5A1Viết hàm truyền vào hai số nguyên a, b. Trả về số lớn hơn trong hai số. def Max_Of_Two( a, b) -> int:

# %%
def Max_Of_Two(a, b):
    return max(a, b)
a=int(input())
b=int(input())
print(Max_Of_Two(a, b))
# Out:
# 6

# %% [markdown]
# #### W5A2 Viết hàm hoán đổi hai số nguyên. def swap(a, b) -> Tuple[int, int]:

# %%
def swap(a, b):
    a, b = b, a
    return a, b

x = int(input("Nhập x: "))
y = int(input("Nhập y: "))

x, y = swap(x, y)

print(f"x = {x}, y = {y}")
# Out:
# x = 6, y = 5

# %% [markdown]
# #### W5A3 Viết hàm kiểm tra một số có phải là số nguyên tố hay không?

# %%
def so_nguyen_to(n):
    if n < 2:
        return "Không phải số nguyên tố"
    
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return "Không phải số nguyên tố"
            
    return "Đây là số nguyên tố"

n = int(input())
print(so_nguyen_to(n))
# Out:
# Đây là số nguyên tố

# %% [markdown]
# #### W5A4 : VIết hàm kiểm tra một số có phải số hoàn hảo hay không, xử lý trên dữ liệu kiểu số nguyên.

# %%
def so_hoan_hao(n):
    tong_uoc_so = 0
    for i in range(1, n):
        if n % i == 0:
            tong_uoc_so += i
    if tong_uoc_so == n:
        return "Đây là số hoàn hảo!"
    else:
        return "Đây không phải số hoàn hảo!"
n=int(input())
print(so_hoan_hao(n))
# Out:
# Đây không phải số hoàn hảo!

# %% [markdown]
# #### W5A5: Viết hàm đưa vào một list số nguyên và một số nguyên dương k. Hãy tìm và trả về vị trí của phần tử đầu tiên có giá trị k trong list số nguyên, nếu không có thì trả về -1

# %%
def check_vi_tri(lst, k):
    for i in range(len(lst)):
        if lst[i] == k:
            return i
    return -1

danh_sach = [10, 20, 30, 20, 40]
so_can_tim = 20
print(check_vi_tri(danh_sach, so_can_tim))
# Out:
# 1

# %% [markdown]
# #### W5A6:  Viết hàm tính giai thừa. Nhập vào số nguyên n, trả về giai thừa của n (n!)

# %%
def giai_thua(n):
    tich = 1
    for i in range(1, n+1):
        tich *= i
    return tich
n=int(input())
print(giai_thua(n))
# Out:
# 120

# %% [markdown]
# #### W5A7
# * Viết hàm giả lập một máy tính bỏ túi.
# * Hàm thực hiện tính toán kết quả của phép toán giữa số \( num1 \) và \( num2 \) với toán tử \( operat
# \)
# * Biết các toán tử đơn giản thực hiện phép toán lần lượt là:
# * Phép trừ \( - \)
# * Phép cộng \( + \)
# * Phép chia \( / \)
# * Phép nhân \( * \)
# * Kết quả làm tròn đến chữ số thập phân thứ hai.
# * Đầu vào: Hai số thực và phép toán cần thực hiện (trong số các phép toán \(+, -, *, /\)).
# * Đầu ra: Kết quả phép toán.

# %%
def may_tinh(num1, num2, dau):
    if dau == "+":
        return num1 + num2
    elif dau == "-":
        return num1-num2
    elif dau == "/":
        return num1/num2
    elif dau == "*":
        return num1 * num2
    
num1=float(input())
num2=float(input())
dau=input("Nhập toán tử muốn thực hiện (+, -, / hoặc *): ")
print(round(may_tinh(num1, num2, dau), 2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 11
#       8     elif dau == "*":
#       9         return num1 * num2
# ---> 11 num1=float(input())
#      12 num2=float(input())
#      13 dau=input("Nhập toán tử muốn thực hiện (+, -, / hoặc *): ")
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# #### W5A8
# #### Khoảng cách Hamming giữa hai số nguyên là số lượng vị trí khác nhau giữa hai dãy bits tương ứng của chúng. Ví dụ: Khoảng cách Hamming giữa 1 (1) và 4 (100) là 2. Cho hai số nguyên x và y, hãy viết hàm trả về khoảng cách Hamming giữa hai số này.

# %%
def hamming_distance(x, y):
    khac_nhau = x ^ y
    khoang_cach = 0
    while khac_nhau > 0:
        if khac_nhau % 2 == 1:
            khoang_cach += 1
        khac_nhau //= 2
    return khoang_cach
x=int(input())
y=int(input())
print(f"Khoảng cách Hamming giữa {x} và {y}: {hamming_distance(x, y)}")
# Out:
# Khoảng cách Hamming giữa 6 và 8: 3

# %% [markdown]
# #### W5A9: Viết hàm trả về tổng các chữ số của số nguyên dương n

# %%
def tong_chu_so(n):
    tong = 0
    for i in n:
        tong += int(i)
    return tong
n=input("Nhập số nguyên dương n: ")
print(f"Tổng các chữ số của {n} là {tong_chu_so(n)}")
# Out:
# Tổng các chữ số của 135 là 9

# %%
def tong_chu_so(n):
    tong = 0
    while n > 0:
        tong += (n % 10)
        n //= 10
    return tong

n = int(input("Nhập số nguyên dương n: "))
print(f"Tổng các chữ số của {n} là {tong_chu_so(n)}")
# Out:
# Tổng các chữ số của 256 là 13

# %% [markdown]
# #### W5A10
# Hai từ được gọi là đẳng cấu nếu các kí tự trong một từ có thể được ánh xạ để được từ còn lại. Ánh
# xạ một kí tự nghĩa là thay đổi toàn bộ các kí tự đó trong từ bởi một kí tự khác. Thứ tự của các kí tự
# được giữ không đổi. Hai kí tự khác nhau không thể ánh xạ đến cùng một kí tự, nhưng một kí tự có
# thể ánh xạ thành chính nó. Ví dụ, từ "abca" và "zbxz" là hai từ đẳng cấu vì ta có thể ánh xạ 'a' thành
# 'z', 'b' thành 'b' và 'c' thành 'x'.
# Viết hàm trả về \(true\) nếu hai từ \(a\) và \(b\) là đẳng cấu, ngược lại \(false\). Bạn có thể giả sử hai
# từ đầu vào có cùng độ dài.

# %%
def la_dang_cau(s, t):
    anh_xa_s2t = {}
    anh_xa_t2s = {}

    for i in range(len(s)):
        chu_s = s[i]
        chu_t = t[i]

        if chu_s in anh_xa_s2t:
            if anh_xa_s2t[chu_s] != chu_t:
                return False
        else:
            if chu_t in anh_xa_t2s:
                return False
            
            anh_xa_s2t[chu_s] = chu_t
            anh_xa_t2s[chu_t] = chu_s
    return True
s=input()
t=input()
print(la_dang_cau(s, t))
# Out:
# False

# %% [markdown]
# #### W5A11: Viết hàm is_product_divisible_by_10(a, b) trả về True nếu tích a*b chia hết cho 10, ngược lại False.

# %%
def is_product_divisible_by_10(a, b):
    if (a*b) % 10 == 0:
        return True
    else:
        return False
a=int(input())
b=int(input())
print(is_product_divisible_by_10(a, b))
# Out:
# False

# %% [markdown]
# #### W5A12
# Viết hàm divide_with_remainder(dividend, divisor) trả về bộ (q, r) sao cho dividend = divisor*q + r và
# 0 <= |r| < |divisor|.

# %%
def divide_with_remainder(dividend, divisor):
    q = dividend // divisor
    r = dividend % divisor
    return (q, r)

dividend=int(input())
divisor=int(input())
divide_with_remainder(dividend, divisor)
# Out:
# (2, 3)

# %% [markdown]
# #### W5A13: Viết hàm max_of_two(a, b) trả về số lớn hơn trong hai số.

# %%
def max_of_two(a, b):
    return max(a, b)
a=int(input())
b=int(input())
print(max_of_two(a, b))
# Out:
# 7

# %% [markdown]
# #### W5A14:  Viết hàm compute(a, b, op) thực hiện phép tính a (+|-|*|/) b tùy theo ký tự op.

# %%
def may_tinh(a, b, op):
    if op == "+":
        return a + b
    elif op == "-":
        return a - b
    elif op == "/":
        return a / b
    elif dau == "*":
        return a * b
    
a=float(input())
b=float(input())
op=input("Nhập toán tử muốn thực hiện (+, -, / hoặc *): ")
print(round(may_tinh(a, b, op), 2))
# Out:
# 0.83

# %% [markdown]
# #### W5A15: Viết hàm is_right_triangle(a, b, c) trả về True nếu ba số có thể là ba cạnh của tam giác vuông.

# %%
def is_right_triangle(a, b, c):
    if a+b>c and a+c>b and b+c>a:
        if a**2 + b**2 == c**2 and b**2 + c**2 == a**2 and c**2 + a**2 == b**2:
            return "Đây là tam giác vuông"
        else:
            return "Không phải tam giác vuông"
    else:
        return "Không phải tam giác"
a=float(input())
b=float(input())
c=float(input())
print(is_right_triangle(a, b, c))
# Out:
# Không phải tam giác
